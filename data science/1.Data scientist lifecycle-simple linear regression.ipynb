# %% [markdown]
# # 1.Data Selection

# %%
print(6|2)
# Out:
# 6

# %% [markdown]
# # 2.Data processing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1.reading the data

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('Advertising.csv')
df.head(100)
# Out:
#     Unnamed: 0     TV  radio  newspaper  sales
# 0            1  230.1   37.8       69.2   22.1
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# ..         ...    ...    ...        ...    ...
# 95          96  163.3   31.6       52.9   16.9
# 96          97  197.6    3.5        5.9   11.7
# 97          98  184.9   21.0       22.0   15.5
# 98          99  289.7   42.3       51.2   25.4
# 99         100  135.2   41.7       45.9   17.2
#
# [100 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# # 2.data cleaning

# %% [markdown]
# performing first data cleaning techniques-like removing duplicate,irrelavant observations

# %% [markdown]
# # missing values addressing

# %%
#finding number of missing values
df.isna().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
#handling missing data
# for now deleting the null value coloumn

new_df = df.dropna(axis = 1, how ='any')      # will drop the column which has atleast one null value

# %%
new_df.isna().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %% [markdown]
# # 3.Exploratory data analysis

# %%
#visualising the relationship between the features and the responses using scatter plots
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline

fig, axs=plt.subplots(1,3, sharey=True)
    
df.plot(kind='scatter',x='TV',y='sales',ax=axs[0],figsize=(16,8))
df.plot(kind='scatter',x='radio',y='sales',ax=axs[1])
# Out:
# <AxesSubplot:xlabel='radio', ylabel='sales'>

# %% [markdown]
# # 4.building linear regression model

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()  #intialising

# %%
x=df[['TV']]  #feature
y=df.sales  #label

lm.fit(x,y)

#through lm.fit()-->training/learning is done, now we are ready for prediction
# Out:
# LinearRegression()

# %% [markdown]
# Now my model is ready

# %%
print(lm.intercept_)
# Out:
# 7.032593549127693

# %%
print(lm.coef_)
# Out:
# [0.04753664]

# %% [markdown]
# # 5.Intercepting the model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Prediction through code
x_new=pd.DataFrame({'TV':[50]})
x_new.head()
# Out:
#    TV
# 0  50

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lm.predict(x_new)
# Out:
# array([9.40942557])

# %% [markdown]
# # 6.checking if model is fitting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If R2 is 0.75, then it means the model is 75% good/ is 75% explaining the data

# %% [markdown]
# R square is used only when we has single feature(ie simple lineare regression model) evaluation

# %%
lm.rsquared
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-1f495b69e67f> in <module>
# ----> 1 lm.rsquared
#
# AttributeError: 'LinearRegression' object has no attribute 'rsquared'

# %% [markdown]
# # Adjusted r squared

# %% [markdown]
# we use multiple features we use it to evaluate the model
